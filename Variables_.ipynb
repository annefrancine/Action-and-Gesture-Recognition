# %% [markdown]
# <a href="https://colab.research.google.com/github/annefrancine/Action-and-Gesture-Recognition/blob/master/Variables_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction à python
#
# Programme :

# %%
# version python
from platform import python_version
print('Version python:', python_version())
# Out:
# Version python: 3.6.9

# %% [markdown]
# 1) Variables
#
# Une variable est une zone de mémoire de l'ordinateur dans lequel une valeur est stockée
#
# *   ne doit pas commencer par un chiffre
# *   ne doit pas contenir d'espace
# *   ne doit pas contenir des caractères spéciaux

# %%
ma_variable_1 = "hello world"
ma_variable_2 = 2
ma_variable_3 = 2.5

# %%
ma_variable_1
# Out:
# 'hello world'

# %%
1x=50
# Out:
#   File "<ipython-input-19-ea2c1bcb5ed7>", line 1
#     1x=50
#      ^
# SyntaxError: invalid syntax

# %%
# la fonction print affiche l'argument 
print(ma_variable_1)
# Out:
# hello world

# %% [markdown]
# #Type de variable
#
# ![image.png](data:image/png;base64,...)

# %%
type(ma_variable_2)
# Out:
# int

# %% [markdown]
# # Déclaration multiple

# %%
person1, person2, person3 = "Anne", "Jean", "Chloe"

# %%
person1
# Out:
# 'Anne'

# %%
person2
# Out:
# 'Jean'

# %%
person3
# Out:
# 'Chloe'

# %%
fruit1 = fruit2 = fruit3 = "Orange"

# %%
fruit1
# Out:
# 'Orange'

# %%
fruit2
# Out:
# 'Orange'

# %%
fruit3
# Out:
# 'Orange'

# %%
Fruit2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e62c125db734> in <module>()
# ----> 1 Fruit2
#
# NameError: name 'Fruit2' is not defined

# %% [markdown]
# Les mots réservés ne peuvent pas etre utilisé comme nom de variable
#
# ![image.png](data:image/png;base64,...)

# %%
break = 1
# Out:
#   File "<ipython-input-20-dbb844e64c6c>", line 1
#     break = 1
#           ^
# SyntaxError: invalid syntax

# %%
# variable affectés à d'autre variables et ordre des opérateurs 
largeur = 2
hauteur  = 4

# %%
aire = largeur * hauteur

# %%
aire
# Out:
# 8

# %%
# l'ordre des opérateurs est le même qu'en mathématiques
perimetre = 2 * (largeur + 2) * hauteur
perimetre
# Out:
# 32
